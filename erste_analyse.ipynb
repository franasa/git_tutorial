# %%
import pandas as pd #pandas importieren
pd.set_option("display.max_columns", None) #command, damit alle Spalten angezeigt werden
data_baume = pd.read_csv('data_tree_register/final_data_techlabs.csv', sep =';') #csv file einlesen und seperator angeben (hier semicolon, sonst komma)
data_baume
# Out:
#                  Y            X                           gml_id       baumid  \
# 0       9.84732768  53.52959226       APP_STRASSENBAUMKATASTER_1  100000174.0
# 1        9.8474086  53.52956652       APP_STRASSENBAUMKATASTER_2  100000175.0
# 2       9.84750309  53.52954069       APP_STRASSENBAUMKATASTER_3  100000176.0
# 3       9.84757352  53.52951773       APP_STRASSENBAUMKATASTER_4  100000177.0
# 4       9.84765448  53.52949379       APP_STRASSENBAUMKATASTER_5  100000178.0
# ...            ...          ...                              ...          ...
# 223310  9.92740534  53.47724258  APP_STRASSENBAUMKATASTER_223307  700086922.0
# 223311  9.92854821  53.4768746   APP_STRASSENBAUMKATASTER_223308  700086924.0
# 223312  9.92770259  53.47713672  APP_STRASSENBAUMKATASTER_223309  700086925.0
# 223313  9.92798735  53.47704579  APP_STRASSENBAUMKATASTER_223310  700086926.0
# 223314  9.97012844  53.43563204  APP_STRASSENBAUMKATASTER_223311  700086956.0
#
#        baumnummer                          gattung gattung_latein  \
# 0        N212-9-1  Robinia / Robinie, Scheinakazie        Robinia
# 1        N212-7-1  Robinia / Robinie, Scheinakazie        Robinia
# 2        N212-6-1  Robinia / Robinie, Scheinakazie        Robinia
# 3        N212-2-1  Robinia / Robinie, Scheinakazie        Robinia
# 4       N212-12-1  Robinia / Robinie, Scheinakazie        Robinia
# ...           ...                              ...            ...
# 223310        NaN                     Alnus / Erle          Alnus
# 223311        NaN                     Alnus / Erle          Alnus
# 223312        NaN                     Alnus / Erle          Alnus
# 223313        NaN                     Alnus / Erle          Alnus
# 223314        NaN                              NaN            NaN
#
#               gattung_deutsch                                   art  \
# 0       Robinie, Scheinakazie  Robinia pseudoacacia / Schein-Akazie
# 1       Robinie, Scheinakazie  Robinia pseudoacacia / Schein-Akazie
# 2       Robinie, Scheinakazie  Robinia pseudoacacia / Schein-Akazie
# 3       Robinie, Scheinakazie  Robinia pseudoacacia / Schein-Akazie
# 4       Robinie, Scheinakazie  Robinia pseudoacacia / Schein-Akazie
# ...                       ...                                   ...
# 223310                   Erle          Alnus spaethii / Späths Erle
# 223311                   Erle          Alnus spaethii / Späths Erle
# 223312                   Erle          Alnus spaethii / Späths Erle
# 223313                   Erle          Alnus spaethii / Späths Erle
# 223314                    NaN                                   NaN
#
#                   art_latein    art_deutsch          sorte_latein  \
# 0       Robinia pseudoacacia  Schein-Akazie  Robinia pseudoacacia
# 1       Robinia pseudoacacia  Schein-Akazie  Robinia pseudoacacia
# 2       Robinia pseudoacacia  Schein-Akazie  Robinia pseudoacacia
# 3       Robinia pseudoacacia  Schein-Akazie  Robinia pseudoacacia
# 4       Robinia pseudoacacia  Schein-Akazie  Robinia pseudoacacia
# ...                      ...            ...                   ...
# 223310        Alnus spaethii    Späths Erle        Alnus spaethii
# 223311        Alnus spaethii    Späths Erle        Alnus spaethii
# 223312        Alnus spaethii    Späths Erle        Alnus spaethii
# 223313        Alnus spaethii    Späths Erle        Alnus spaethii
# 223314                   NaN            NaN                   NaN
#
#         sorte_deutsch  pflanzjahr  pflanzjahr_portal  kronendurchmesser  \
# 0       Schein-Akazie      1980.0             1980.0                7.0
# 1       Schein-Akazie      1980.0             1980.0                7.0
# 2       Schein-Akazie      1980.0             1980.0                7.0
# 3       Schein-Akazie      1980.0             1980.0                6.0
# 4       Schein-Akazie      1987.0             1987.0                5.0
# ...               ...         ...                ...                ...
# 223310    Späths Erle         0.0                NaN                0.0
# 223311    Späths Erle         0.0                NaN                0.0
# 223312    Späths Erle         0.0                NaN                0.0
# 223313    Späths Erle         0.0                NaN                0.0
# 223314            NaN      1988.0             1988.0                6.0
#
#        kronendurchmesser_z  stammumfang stammumfang_z  \
# 0                      7 m        115.0        115 cm
# 1                      7 m        117.0        117 cm
# 2                      7 m        111.0        111 cm
# 3                      6 m         94.0         94 cm
# 4                      5 m         73.0         73 cm
# ...                    ...          ...           ...
# 223310                 NaN          0.0           NaN
# 223311                 NaN          0.0           NaN
# 223312                 NaN          0.0           NaN
# 223313                 NaN         20.0         20 cm
# 223314                 6 m         47.0         47 cm
#
#                         strasse hausnummer  ortsteil_nr     stadtteil  \
# 0                Neuer Sielpool         31        141.0  Finkenwerder
# 1                Neuer Sielpool         31        141.0  Finkenwerder
# 2                Neuer Sielpool         31        141.0  Finkenwerder
# 3                Neuer Sielpool         31        141.0  Finkenwerder
# 4                Neuer Sielpool          1        141.0  Finkenwerder
# ...                         ...        ...          ...           ...
# 223310          Fürstenmoordamm        NaN        711.0      Heimfeld
# 223311          Fürstenmoordamm        NaN        711.0      Heimfeld
# 223312          Fürstenmoordamm        NaN        711.0      Heimfeld
# 223313          Fürstenmoordamm        NaN        711.0      Heimfeld
# 223314  Marmstorfer Schützenweg         28        709.0     Marmstorf
#
#                bezirk  Spalte1
# 0       Hamburg-Mitte      NaN
# 1       Hamburg-Mitte      NaN
# 2       Hamburg-Mitte      NaN
# 3       Hamburg-Mitte      NaN
# 4       Hamburg-Mitte      NaN
# ...               ...      ...
# 223310        Harburg      NaN
# 223311        Harburg      NaN
# 223312        Harburg      NaN
# 223313        Harburg      NaN
# 223314        Harburg      NaN
#
# [223315 rows x 25 columns]

# %%
data_baume.describe() #gibt summary statistics aus mittelwert, median, STD und co.
# Out:
#              baumid     pflanzjahr  pflanzjahr_portal  kronendurchmesser  \
# count  2.233110e+05  223311.000000      220974.000000      223311.000000
# mean   3.907751e+08    1950.363095        1970.989949           8.566331
# std    1.921103e+08     211.344464          66.957942           4.261755
# min    1.000001e+08       0.000000           0.000000           0.000000
# 25%    2.000480e+08    1958.000000        1959.000000           5.000000
# 50%    4.000403e+08    1979.000000        1979.000000           8.000000
# 75%    5.001443e+08    1992.000000        1992.000000          11.000000
# max    7.000870e+08    2018.000000        2018.000000          56.000000
#
#          stammumfang    ortsteil_nr  Spalte1
# count  223311.000000  223225.000000      0.0
# mean      120.404046     408.069997      NaN
# std        67.182458     187.982250      NaN
# min         0.000000     101.000000      NaN
# 25%        74.000000     221.000000      NaN
# 50%       113.000000     429.000000      NaN
# 75%       157.000000     525.000000      NaN
# max      1961.000000     718.000000      NaN

# %%
data_baume.info() # infos über Anzahl Zeilen, Spalten, Datentyp etc.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 223315 entries, 0 to 223314
# Data columns (total 25 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Y                    223309 non-null  object
#  1   X                    223309 non-null  object
#  2   gml_id               223313 non-null  object
#  3   baumid               223311 non-null  float64
#  4   baumnummer           222190 non-null  object
#  5   gattung              222299 non-null  object
#  6   gattung_latein       222299 non-null  object
#  7   gattung_deutsch      222297 non-null  object
#  8   art                  222297 non-null  object
#  9   art_latein           222297 non-null  object
#  10  art_deutsch          222297 non-null  object
#  11  sorte_latein         222297 non-null  object
#  12  sorte_deutsch        222297 non-null  object
#  13  pflanzjahr           223311 non-null  float64
#  14  pflanzjahr_portal    220974 non-null  float64
#  15  kronendurchmesser    223311 non-null  float64
#  16  kronendurchmesser_z  222469 non-null  object
#  17  stammumfang          223311 non-null  float64
#  18  stammumfang_z        222304 non-null  object
#  19  strasse              222338 non-null  object
#  20  hausnummer           213427 non-null  object
#  21  ortsteil_nr          223225 non-null  float64
#  22  stadtteil            223225 non-null  object
#  23  bezirk               223309 non-null  object
#  24  Spalte1              0 non-null       float64
# dtypes: float64(7), object(18)
# memory usage: 42.6+ MB

# %%
data_baume['bezirk'].hist(xrot=30) Histogram der Verteilung der Datenpunkte über Bezirke
# Out:
# <AxesSubplot:>
